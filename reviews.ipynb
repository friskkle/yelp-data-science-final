# %%
import pandas as pd
import numpy as np

df = pd.read_json("./archive/yelp_academic_dataset_review.json", nrows=50000, lines=True)
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# ...

# %%
df.describe()
# Out:
#               stars        useful         funny          cool
# count  50000.000000  50000.000000  50000.000000  50000.000000
# mean       3.848000      0.889540      0.250440      0.345060
# std        1.350308      1.864481      0.941455      1.072388
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      0.000000      0.000000
# 75%        5.000000      1.000000      0.000000      0.000000
# max        5.000000     91.000000     38.000000     49.000000

# %%
business_id = "XQfwVwDr-v0ZS3_CbbE5Xw"
selected_data = df[df["business_id"] == "kxX2SOes4o-D3ZQBkiMRfA"]
selected_data.head()
selected_data
# Out:
#                     review_id                 user_id             business_id  \
# 3      AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 148    HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 526    EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 4777   T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 7561   NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
# 8110   l-bH0C-PSXmVs-vQqMfJ1Q  toFm0jWZJKqsOmHE7kMbRA  kxX2SOes4o-D3ZQBkiMRfA
# 8134   qr7acpL3ZzP7cAmXaax93w  cMvau1VAjuKo_ah0ZBck1g  kxX2SOes4o-D3ZQBkiMRfA
# 8848   E2rc2AjhzYxtoVQigrTpvg  DVMopL-MS3_03qMW0Dxa1A  kxX2SOes4o-D3ZQBkiMRfA
# 10010  3mtQ9nqWoyZjgidMQR6uxg  rmYqxdycak7SL9vY7xE21A  kxX2SOes4o-D3ZQBkiMRfA
# 11730  T4eUUk_WL-m_wbfjczt8WQ  MpIZMLdDjZRu5BzGyEjEOw  kxX2SOes4o-D3ZQBkiMRfA
# 13569  TdmWqB-77Lirm-XgA4JJ4A  3fTw9hmzlbMK2Q32Q-a4Hw  kxX2SOes4o-D3ZQBkiMRfA
# ...

# %%
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

df = df[df["stars"] != 3]

text_collection = df["text"].to_list()
text = " ".join(review for review in text_collection)

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure(figsize=(8, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize
